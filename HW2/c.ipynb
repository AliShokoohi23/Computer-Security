# %%
import csv
import math
from random import randint, uniform

class CipherSolver:
    def __init__(self):
        # Genetic Algorithm Parameters
        self.num_generations = 500
        self.population_size = 500
        self.tournament_size = 20
        self.tournament_probability = 0.75
        self.crossover_rate = 0.65
        self.num_crossover_points = 5
        self.mutation_rate = 0.2
        self.elitism_rate = 0.15
        self.selection_type = 'TS'
        self.stagnation_limit = 100

        # Weight parameters
        self.bigram_weight = 0.0
        self.trigram_weight = 1.0

        # Usage parameters
        self.verbose_mode = False

        # Default variables
        self.alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
        self.num_elites = int(self.elitism_rate * self.population_size)
        self.num_offsprings = self.population_size - self.num_elites

        self.tournament_probabilities = [self.tournament_probability]

        for i in range(1, self.tournament_size):
            probability = self.tournament_probabilities[i - 1] * (1.0 - self.tournament_probability)
            self.tournament_probabilities.append(probability)

    def load_ngram_frequencies(self, filename):
        ngram_frequencies = {}
        
        with open(filename, 'r') as file:
            reader = csv.reader(file)

            header_skipped = False
            for key, value in reader:
                if not header_skipped:
                    header_skipped = True
                    continue
                
                ngram_frequencies[key] = value

        return ngram_frequencies

    def extract_ngrams(self, text, n):
        ngrams = [text[i:i + n] for i in range(len(text) - n + 1)]

        valid_ngrams = []
        for ngram in ngrams:
            if ngram.isalpha():
                ngram_upper = ngram.upper()
                valid_ngrams.append(ngram_upper)

        return valid_ngrams

    def decrypt_with_key(self, key):
        letter_map = {}

        for i in range(26):
            k = self.alphabet[i]
            v = key.upper()[i]

            letter_map[k] = v

        decrypted_text = ''
        for char in self.cipher_text:
            if char not in self.alphabet:
                decrypted_text += char
            else:
                decrypted_text += letter_map[char]

        return decrypted_text

    def compute_fitness(self, text):
        bigrams = self.extract_ngrams(text, 2)
        trigrams = self.extract_ngrams(text, 3)
        
        bigram_score = 0
        if self.bigram_weight > 0:
            for bigram in bigrams:
                if bigram in self.bigram_frequencies:
                    frequency = int(self.bigram_frequencies[bigram])
                    bigram_score += math.log2(frequency)
        
        trigram_score = 0
        if self.trigram_weight > 0:    
            for trigram in trigrams:
                if trigram in self.trigram_frequencies:
                    frequency = int(self.trigram_frequencies[trigram])
                    trigram_score += math.log2(frequency)
            
        fitness_score = (bigram_score * self.bigram_weight) + (trigram_score * self.trigram_weight)
        return fitness_score

    def combine_keys(self, key1, key2):
        offspring = [None] * 26
        count = 0
        while count < self.num_crossover_points:
            r = randint(0, len(key1) - 1)

            if offspring[r] is None:
                offspring[r] = key1[r]
                count += 1
        
        for char in key2:
            if char not in offspring:
                for i in range(len(offspring)):
                    if offspring[i] is None:
                        offspring[i] = char
                        break

        return ''.join(offspring)

    def mutate_key(self, key):
        a = randint(0, len(key) - 1)
        b = randint(0, len(key) - 1)

        key = list(key)
        temp = key[a]
        key[a] = key[b]
        key[b] = temp

        return ''.join(key)

    def initialize_population(self):
        population = []
        
        for _ in range(self.population_size):
            key = ''

            while len(key) < 26:
                r = randint(0, len(self.alphabet) - 1)
                
                if self.alphabet[r] not in key:
                    key += self.alphabet[r]

            population.append(key)
        
        return population

    def evaluate_population(self, population):
        fitness_scores = []

        for key in population:
            decrypted_text = self.decrypt_with_key(key)
            key_fitness = self.compute_fitness(decrypted_text)
            fitness_scores.append(key_fitness)

        return fitness_scores

    def apply_elitism(self, population, fitness_scores):
        population_fitness = {}
        
        for i in range(self.population_size):
            key = population[i]
            value = fitness_scores[i]

            population_fitness[key] = value

        population_fitness = {k: v for k, v in sorted(population_fitness.items(), key=lambda item: item[1])}
        sorted_population = list(population_fitness.keys())

        elite_population = sorted_population[-self.num_elites:]

        return elite_population

    def roulette_wheel_select(self, fitness_scores):
        index = -1
        max_probability = max(fitness_scores)
            
        selected = False
        while not selected:
            index = randint(0, self.population_size - 1)
            probability = fitness_scores[index]

            r = uniform(0, max_probability)
            selected = (r < probability)
        
        return index

    def select_via_tournament(self, population, fitness_scores):
        remaining_population = population.copy()
        selected_keys = []

        for _ in range(2):
            tournament = {}
            
            for _ in range(self.tournament_size):
                r = randint(0, len(remaining_population) - 1)
                key = remaining_population[r]
                key_fitness = fitness_scores[r]

                tournament[key] = key_fitness
                remaining_population.pop(r)

            sorted_tournament = {k: v for k, v in sorted(tournament.items(), key=lambda item: item[1], reverse=True)}
            tournament_keys = list(sorted_tournament.keys())
            
            index = -1
            selected = False
            while not selected:
                index = randint(0, self.tournament_size - 1)
                probability = self.tournament_probabilities[index]

                r = uniform(0, self.tournament_probability)
                selected = (r < probability)
        
            selected_keys.append(tournament_keys[index])

        return selected_keys[0], selected_keys[1]

    def reproduce_population(self, population, fitness_scores):
        new_population = []

        while len(new_population) < self.num_offsprings:
            parent1, parent2 = None, None

            if self.selection_type == 'RWS':
                parent1_index = self.roulette_wheel_select(fitness_scores)
                parent2_index = self.roulette_wheel_select(fitness_scores)

                parent1 = population[parent1_index]
                parent2 = population[parent2_index]
            else:
                parent1, parent2 = self.select_via_tournament(population, fitness_scores)

            offspring1 = self.combine_keys(parent1, parent2)
            offspring2 = self.combine_keys(parent2, parent1)

            new_population += [offspring1, offspring2]
        
        new_population = self.mutate_population(new_population, self.num_offsprings)

        return new_population
        
    def mutate_population(self, population, pop_size):
        for i in range(pop_size):
            r = uniform(0, 1)

            if r < self.mutation_rate:
                key = population[i]
                mutated_key = self.mutate_key(key)

                population[i] = mutated_key

        return population

    def format_to_plaintext(self, decrypted_text):
        plaintext = list(decrypted_text)
        for i in range(len(plaintext)):
            if self.case_flags[i]:
                plaintext[i] = plaintext[i].lower()
        plaintext = ''.join(plaintext)
        
        return plaintext

    def solve(self, cipher_text = ''):
        # Defining cipher_text
        self.cipher_text = cipher_text
        
        # Checking if cipher_text is valid
        if self.cipher_text == '':
            message = (
                '\n(CipherSolver) Cipher text is invalid. Use solve() as such:\n'
                '\tsolver = CipherSolver()\n'
                '\tsolver.solve("Example cipher text")'
            )
            print(message)
            return

        # Formatting cipher_text
        self.case_flags = [ch.islower() and ch.isalpha() for ch in self.cipher_text]
        self.cipher_text = self.cipher_text.upper()

        # Loading pre-computed ngram frequencies
        bigram_filename = 'data/bi-ngramFrequency.csv'
        self.bigram_frequencies = self.load_ngram_frequencies(bigram_filename)

        trigram_filename = 'data/tri-ngramFrequency.csv'
        self.trigram_frequencies = self.load_ngram_frequencies(trigram_filename)
        
        # Main Program
        population = self.initialize_population()
        
        max_fitness = 0
        stagnation_counter = 0
        for gen_no in range(self.num_generations + 1):
            # Evolving population
            fitness_scores = self.evaluate_population(population)

            # Extracting top solutions
            elite_population = self.apply_elitism(population, fitness_scores)
            reproduction_population = self.reproduce_population(population, fitness_scores)
            population = elite_population + reproduction_population

            # Evaluating population
            max_population_fitness = max(fitness_scores)
            if max_population_fitness > max_fitness:
                max_fitness = max_population_fitness
                stagnation_counter = 0
            else:
                stagnation_counter += 1
            
            index = fitness_scores.index(max_fitness)
            key = population[index]
            decrypted_text = self.decrypt_with_key(key)
            # Verbose Logging
            if self.verbose_mode:
                plaintext = self.format_to_plaintext(decrypted_text)  
                print(f'[INFO] Best fitness (Gen-{gen_no}):', max_fitness)
                print('Key:', key)
                print('Decrypted Text:\n' + plaintext + '\n')
                
            # Checking if stagnated
            if stagnation_counter >= self.stagnation_limit:
                if self.verbose_mode:
                    print('[INFO] Program converged. Stopping execution...\n')
                break
        # Returning plaintext
              
        # Logging final results
        max_population_fitness = max(fitness_scores)
        index = fitness_scores.index(max_population_fitness)
        best_key = population[index]
        decrypted_text = self.decrypt_with_key(best_key)

            
        return plaintext

# %%
# Initializing GeneticSolver object
solver = CipherSolver()

# Changing parameters in the GeneticSolver object, if needed.
solver.verbose_mode = True

ciphertext = "..."

# The function solve() requires the ciphertext as an argument, and returns the plaintext.
plaintext = solver.solve(ciphertext)
print(plaintext)
# Out:
# [INFO] Best fitness (Gen-0): 1284.649798074016
# Key: VRCWUDOYMPZKIAGEFSJXTLQBHN
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-1): 1284.649798074016
# Key: RCZOMLSNFYAGWQUJVHBKDIXPTE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-2): 1476.9928954823247
# Key: FHQBXYRNATIVJGSDOMCLZKPEUW
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-3): 1476.9928954823247
# Key: PGKUWQIYFXRCNAJDZHBMSTOVLE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-4): 1476.9928954823247
# Key: PGKUWQIYFXRCNAJDZHBMSTOVLE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-5): 1476.9928954823247
# Key: PGKUWQIYFXRCNAJDZHBMSTOVLE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-6): 1530.780065911985
# Key: ROYFWKAUPNMGCBXJVZHQILSDTE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-7): 1682.4997911054757
# Key: PUVYGSIJACQNKWZFXDOBMHTRLE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-8): 1682.4997911054757
# Key: GUKWQAIRYFNXCSJZHMBPDTOLVE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-9): 1682.4997911054757
# Key: GUKWQAIRYFNXCSJZHMBPDTOLVE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-10): 1753.1171646176304
# Key: ROYFWKECAUPNLMGJBXVZHQISDT
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-11): 1753.1171646176304
# Key: ROTFWKACPNUGMBXJZHQVDLISYE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-12): 1806.0887202381425
# Key: LDRNWKCFABPXQYZJVUHTIOGSME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-13): 1890.3043157842494
# Key: LDBWKAUNPMCYXFJZVQIHRSOGTE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-14): 2158.369668768314
# Key: OFWYAMIPTRGSCBXQJKVUZLHNDE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-15): 2158.369668768314
# Key: LADWRKICSUNZFPXQBYJVHTOGME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-16): 2172.2278853768707
# Key: ROFYKWAUPMTGCBXJVZHQLSINDE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-17): 2172.2278853768707
# Key: LAVXGWIYDHNBPCFZQUKJSROTME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-18): 2172.2278853768707
# Key: LAVXGWIYDHNBPCFZQUKJSROTME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-19): 2172.2278853768707
# Key: LAVXGWIYDHNBPCFZQUKJSROTME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-20): 2196.009182599505
# Key: LAKDRWISNYCBPZFXUJQVHTGOME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-21): 2198.096631771325
# Key: LAYVWGIPDHNBFCXUZJQKSROTME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-22): 2228.373380308856
# Key: RAVKPWISDUNBCFXZQYJHLTOGME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-23): 2299.6821625547877
# Key: LABFYGWKIPSHNRCDXJUQZVOTME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-24): 2376.1757472150516
# Key: LADWRVXCGIYMBFNPKZQSJUHOTE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-25): 2376.1757472150516
# Key: LAXWGRIYDPNBCFQJZUKSHTOMVE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-26): 2376.1757472150516
# Key: LAXWGRIYDPNBCFQJZUKSHTOMVE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-27): 2376.1757472150516
# Key: LAXWGRIYDPNBCFQJZUKSHTOMVE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-28): 2376.1757472150516
# Key: LAXWGRIYDPNBCFQJZUKSHTOMVE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-29): 2505.3646302153943
# Key: LAVXGIYDNCFPBWQJZUKHTSORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-30): 2505.3646302153943
# Key: LAPXGWIYDVNBCFQJZUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-31): 2532.0375655515472
# Key: LAVWFGIDHYNBCPXQZUKJSROTME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-32): 2553.589997543314
# Key: LUAVXGYIWPDBFNCKZQJHSTROME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-33): 2655.832249009923
# Key: LAXKGWYRDIBPCNJFQZUSHOTVME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-34): 2655.832249009923
# Key: LAXWGYIDVPNFCBQJZUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-35): 2655.832249009923
# Key: LAXWGYIDVPNFCBQJZUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-36): 2655.832249009923
# Key: LAXWGYIDVPNFCBQJZUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-37): 2688.2818976579433
# Key: LAXGYIDVNWBFCPJZQUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-38): 2688.2818976579433
# Key: LAWXGDIYVPNBCFQJZUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-39): 2694.3528929087333
# Key: LAVPGXKOWINDYBFCQJUSHTZRME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-40): 2767.5006051780124
# Key: LAXGWYIDVNFBCPJQZUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-41): 2797.235907652003
# Key: LAXGWDIYVPNFCBQJZUKSHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-42): 2797.235907652003
# Key: LAXVGDISPWNBRFZQJUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-43): 2882.6969389662117
# Key: LXWDVIYGBPNFCQJZUSKOHTARME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-44): 2915.114588746932
# Key: LAXWSDIYVPNBFJQUCZKGHTORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-45): 2915.114588746932
# Key: LAXWGDISVPNBRFZJQUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-46): 2927.104513355939
# Key: LAXWGDIYVPNKRCBJFZUQSHTOME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-47): 2953.153584494561
# Key: AXWLGYIDVPNFQBZJSTUKHCORME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-48): 2953.153584494561
# Key: LIXWVGASDPNBRFQZJUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-49): 2953.153584494561
# Key: LIXWVGASDPNBRFQZJUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-50): 2955.191227198456
# Key: LAXGDISPVWNBRFQZUKJYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-51): 2955.191227198456
# Key: LIXWGDASVPNBRFQZJUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-52): 2956.956171914931
# Key: LAWXGDISVPZBRFQNJUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-53): 2965.531429162632
# Key: LIWXGFDASVPBNRQJZUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-54): 2999.472375161278
# Key: LIXGDASRNVBPFZJQUKYHOTCWME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-55): 2999.472375161278
# Key: LIXWGDACVPNBRFQJZUKYHTOSME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-56): 2999.472375161278
# Key: LIXWGDACVPNBRFQJZUKYHTOSME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-57): 2999.472375161278
# Key: LIXWGDACVPNBRFZQJUKYHTOSME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-58): 3051.038908195817
# Key: LIWDAGSXVPNBQRFJZUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-59): 3051.038908195817
# Key: LIWXDGACVPNBRFZQJUKYHTOSME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-60): 3106.0596145292166
# Key: LIWXASGPVDNFRBQJZUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-61): 3106.0596145292166
# Key: LIXWDGACVPNFRBQJZUMYHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-62): 3107.0596145292166
# Key: LIWXDGACVPNBRFQJZUKYHTOSME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-63): 3110.0596145292166
# Key: LIWXDBGAVSPNRFQJZUKYHTOCME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-64): 3110.0596145292166
# Key: LIXWDGACVPNFRBJZQUMYHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-65): 3200.5990203154756
# Key: LIXWDGACVPNFRBQJZUKMYHOSTE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-66): 3200.5990203154756
# Key: LIXYDGACVPNFRBJZQUMWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-67): 3200.5990203154756
# Key: LIXYDGACVPNFRBJZQUMWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-68): 3200.5990203154756
# Key: LIXYDGACVPNFRBJZQUMWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-69): 3200.5990203154756
# Key: LIXYDGACVPNFRBJZQUMWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-70): 3200.5990203154756
# Key: LIXYDGACVPNFRBJZQUMWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-71): 3200.5990203154756
# Key: LIXYDGACVPNFRBJZQUMWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-72): 3200.5990203154756
# Key: LIXYDGACVPNFRBJZQUMWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-73): 3231.0575222000384
# Key: LIXYGWDCVPNFRBZQJUKMHTOSEA
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-74): 3231.0575222000384
# Key: LIMYDGACVPNFRBJQZUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-75): 3231.0575222000384
# Key: LIMYDGACVPNFRBJQZUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-76): 3233.6424847007597
# Key: LIXYDGACVPNFRJQZUMWHBTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-77): 3233.6424847007597
# Key: LIMYDGACVPNFRBZJQUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-78): 3233.6424847007597
# Key: LIMYDGACVPNFRBZJQUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-79): 3233.6424847007597
# Key: LIMYDGACVPNFRBQJZUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-80): 3233.6424847007597
# Key: LIMYDGACVPNFRBZJQUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-81): 3234.0575222000384
# Key: LIYDCGAVNPRFBZJQUMWHTOSKXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-82): 3234.0575222000384
# Key: LIMYDGACVPNFRBJZQUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-83): 3234.0575222000384
# Key: LIMYDGACVPNFRBJZQUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-84): 3237.149912945109
# Key: LIYMDGACVPNFRBQZJUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-85): 3252.871054961148
# Key: LIXYDGACVPNRBFZQJUKWHTOSME
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-86): 3252.871054961148
# Key: LIMYDGACVPNKRBQJZUFWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-87): 3252.871054961148
# Key: LIMYDGACVPNKRBQJZUFWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-88): 3252.871054961148
# Key: LIMYDGACVPNKRBQJZUFWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-89): 3253.2860924604265
# Key: LIMYDGACVPNKQRZJUBFWSHOTXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-90): 3253.2860924604265
# Key: LIMYDGACVPNKRBJZQUFWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-91): 3263.7393854644033
# Key: LIMYAGDCVPNRBQFJZUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-92): 3263.7393854644033
# Key: LIMYDGACVPNKRBZQJUXWHTOSFE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-93): 3268.2009436201283
# Key: LIYXADGCVPNQRFJBKZUMWHTOSE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-94): 3275.432536711053
# Key: LIMYDGACVPNZQRFBJUKWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-95): 3275.8041522336257
# Key: LIMXYDGCVAPNFEBQJZUKHWTOSR
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-96): 3291.3870965580527
# Key: LIMYXGDVCANPRZJQUBFHWTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-97): 3301.8762755200833
# Key: LIMYDGACVPNKQRUBJFZWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-98): 3301.8762755200833
# Key: LIMYDGACVPNKRUBQZFJWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-99): 3303.3423832035774
# Key: RIMYXDGACVNKPLUQZBJFHWTOSE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-100): 3303.3423832035774
# Key: LIMYDGACVPNKRUZQJFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-101): 3303.3423832035774
# Key: LIMYDGACVPNKRUZQJFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-102): 3303.3423832035774
# Key: LIMYDGACVPNKRUZQJFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-103): 3304.3423832035774
# Key: LIMYDGACVNKRQPBFUJZWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-104): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-105): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-106): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-107): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-108): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-109): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-110): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-111): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-112): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-113): 3304.3423832035774
# Key: LIMYDGACVPNKRUJQZFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-114): 3308.9032333749374
# Key: LIMYDGACVPNRUZFKQWXJBHTSOE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-115): 3308.9032333749374
# Key: LIMYDGACVPNXRUJQZFKWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-116): 3308.9032333749374
# Key: LIMYDGACVPNXRUJQZFKWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-117): 3320.5587501530263
# Key: LIMYDGACVPNKRUZQBFJWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-118): 3320.5587501530263
# Key: LIMYDGACVPNKRUXQZFBWHTOSJE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-119): 3320.5587501530263
# Key: LIMYDGACVPNKRUXQZFBWHTOSJE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-120): 3320.5587501530263
# Key: LIMYDGACVPNKRUXQZFBWHTOSJE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-121): 3320.5587501530263
# Key: LIMYDGACVPNKRUXQZFBWHTOSJE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-122): 3320.5587501530263
# Key: LIMYDGACVPNKRUXQZFBWHTOSJE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-123): 3330.50442381214
# Key: RIMYDGACVLNBPXZUQJHWFKTSOE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-124): 3330.50442381214
# Key: LIMYDGACVPNKRUJQZFXWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-125): 3330.50442381214
# Key: LIMYDGACVPNKRUJQZFXWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-126): 3330.50442381214
# Key: LIMYDGACVPNKRUJQZFXWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-127): 3330.50442381214
# Key: LIMYDGACVPNKRUJQZFXWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-128): 3330.50442381214
# Key: LIMYDGACVPNKRUJQZFXWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-129): 3330.9361559160325
# Key: LIDYGVACPNUJRKFZQMBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-130): 3330.9361559160325
# Key: LIMYDGACVPNKRUXJQFZWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-131): 3345.3057532623116
# Key: LIMYDGACVPNXRUJZBFKWHQTSOE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-132): 3345.3057532623116
# Key: LIMYDGACVPNKRUXQJFZWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-133): 3345.3057532623116
# Key: LIMYDGACVPNKRUXQJFZWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-134): 3430.3800524663925
# Key: LIMYDGACVPNKURZXQFJWHTOBSE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-135): 3430.3800524663925
# Key: LIVYDGACMPNBRUQZJFXWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-136): 3434.5761914664254
# Key: LIMYDGBACVWNPURQJXFZKTOHSE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-137): 3434.5761914664254
# Key: LIVYDGACMPNKRUQZJFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-138): 3434.5761914664254
# Key: LIVYDGACMPNKRUQZJFBWHTOSXE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-139): 3448.919574814114
# Key: LIVMYDGCAPNRUJQFZXWHTOSBKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-140): 3449.5307513134253
# Key: LIMYDGACVPNKRUXZQFBWHTOSJE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-141): 3458.9924889734816
# Key: LIYGDAMCVUNKRPZQXJFWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-142): 3458.9924889734816
# Key: LIVYDGACMPNBRUXZQFJWHTOSKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-143): 3489.088861479628
# Key: LIVYDGAMCJNRKUQBZPFXWHTOSE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-144): 3489.088861479628
# Key: LIVYDGACMPNKRUZQXFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-145): 3489.088861479628
# Key: LIVYDGACMPNKRUZQXFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-146): 3489.088861479628
# Key: LIVYDGACMPNKRUZQXFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-147): 3489.088861479628
# Key: LIVYDGACMPNKRUZQXFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-148): 3494.494121372159
# Key: LIVYDAGCMPNRUQXJZWFHTOSBKE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-149): 3494.494121372159
# Key: LIVYDGACMPNKRUXQJFZWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-150): 3505.3052284290775
# Key: LIVYDGCAMNPRKBUJZXFHQTOWSE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-151): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-152): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-153): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-154): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-155): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-156): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-157): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-158): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-159): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-160): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-161): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-162): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-163): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-164): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-165): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-166): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-167): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-168): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-169): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-170): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-171): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-172): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-173): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-174): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-175): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-176): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-177): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-178): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-179): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-180): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-181): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-182): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-183): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-184): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-185): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-186): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-187): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-188): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-189): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-190): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-191): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-192): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-193): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-194): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-195): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-196): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-197): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-198): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-199): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-200): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-201): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-202): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-203): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-204): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-205): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-206): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-207): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-208): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-209): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-210): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-211): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-212): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-213): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-214): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-215): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-216): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-217): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-218): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-219): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-220): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-221): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-222): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-223): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-224): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-225): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-226): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-227): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-228): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-229): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-230): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-231): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-232): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-233): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-234): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-235): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-236): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-237): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-238): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-239): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-240): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-241): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-242): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-243): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-244): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-245): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-246): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-247): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-248): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-249): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Best fitness (Gen-250): 3505.3052284290775
# Key: LIVYDGACMPNKRUXQZFJWHTOSBE
# Decrypted Text:
# ...
#
# [INFO] Program converged. Stopping execution...
#
# ...
